# %%
import pandas as pd
import numpy as np

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
ice_cream_flavors = ["Chocolate", "Vanilla", "Strawberry", "Rum Raisin"]

# %%
pd.Series(ice_cream_flavors)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
pd.Series(data=ice_cream_flavors)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
my_series = pd.Series(ice_cream_flavors)
my_series
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
my_series[2]
# Out:
# 'Strawberry'

# %%
my_series[0:2]
# Out:
# 0    Chocolate
# 1      Vanilla
# dtype: object

# %%
days_of_week = ("Monday", "Wednesday", "Friday", "Saturday")
pd.Series(ice_cream_flavors, days_of_week)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Friday       Strawberry
# Saturday     Rum Raisin
# dtype: object

# %%
pd.Series(data=ice_cream_flavors, index=days_of_week)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Friday       Strawberry
# Saturday     Rum Raisin
# dtype: object

# %%
my_favorite_flavor = pd.Series(data=ice_cream_flavors, index=days_of_week)

# %%
my_favorite_flavor["Wednesday"]
# Out:
# 'Vanilla'

# %%
my_favorite_flavor[1]
# Out:
# C:\Users\lorra\AppData\Local\Temp\ipykernel_12584\4194471524.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   my_favorite_flavor[1]
# 'Vanilla'

# %%
my_favorite_flavor.iloc[1]
# Out:
# 'Vanilla'

# %%
bunch_of_bools = [True, False, False]
pd.Series(bunch_of_bools)
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
stock_prices = [985.32, 950.44]
time_of_day = ["Open", "Close"]
pd.Series(data = stock_prices, index = time_of_day)
# Out:
# Open     985.32
# Close    950.44
# dtype: float64

# %%
lucky_numbers = [4, 8, 15, 16, 23, 42]
pd.Series(lucky_numbers)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
lucky_numbers = [4, 8, 15, 16, 23, 42]
pd.Series(lucky_numbers, dtype="float")
# Out:
# 0     4.0
# 1     8.0
# 2    15.0
# 3    16.0
# 4    23.0
# 5    42.0
# dtype: float64

# %%
temperatures = [94, 88, np.nan, 91]
pd.Series(data = temperatures)
# Out:
# 0    94.0
# 1    88.0
# 2     NaN
# 3    91.0
# dtype: float64

# %%
calorie_info = { 
    "Cereal" : 125,
    "Chocolate Bar" : 406,
    "Ice Cream Sundae" : 342,
}
diet = pd.Series(calorie_info)
diet
# Out:
# Cereal              125
# Chocolate Bar       406
# Ice Cream Sundae    342
# dtype: int64

# %%
pd.Series(data= ('Red', 'Green', 'Blue'))
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
# To create a Series that stores tuples, wrap the tuples in a list
rgb_colors = [ (120, 41, 26), (196, 165, 45)]
pd.Series(rgb_colors)
# Out:
# 0     (120, 41, 26)
# 1    (196, 165, 45)
# dtype: object

# %%
my_set = { 'Ricky', 'Bobby' }
pd.Series(data = list(my_set))
# Out:
# 0    Bobby
# 1    Ricky
# dtype: object

# %%
random_data = np.random.randint(1, 101, 10)
random_data
# Out:
# array([77, 25, 67, 49, 19, 48, 18, 37, 86,  1], dtype=int32)

# %%
pd.Series(random_data)
# Out:
# 0    77
# 1    25
# 2    67
# 3    49
# 4    19
# 5    48
# 6    18
# 7    37
# 8    86
# 9     1
# dtype: int32

# %%
type(random_data)
# Out:
# numpy.ndarray

# %%
diet.values
# Out:
# array([125, 406, 342])

# %%
type(diet.values)
# Out:
# numpy.ndarray

# %%
diet.index
# Out:
# Index(['Cereal', 'Chocolate Bar', 'Ice Cream Sundae'], dtype='object')

# %%
type(diet.index)
# Out:
# pandas.core.indexes.base.Index

# %%
diet.dtype
# Out:
# dtype('int64')

# %%
diet.size
# Out:
# 3

# %%
diet.shape
# Out:
# (3,)

# %%
diet.is_unique
# Out:
# True

# %%
pd.Series(data = [3,3]).is_unique
# Out:
# False

# %%
pd.Series(data = [1, 6, 3]).is_monotonic_increasing
# Out:
# False

# %%
pd.Series(data = [1, 6, 3]).is_monotonic_decreasing
# Out:
# False

# %%
# generate 100-value range of numbers between 0 and 500 in increments of 5
values = range(0, 500, 5)
nums = pd.Series(data = values)
nums
# Out:
# 0       0
# 1       5
# 2      10
# 3      15
# 4      20
#      ...
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# Length: 100, dtype: int64

# %%
nums.head(3)
# Out:
# 0     0
# 1     5
# 2    10
# dtype: int64

# %%
nums.tail(6)
# Out:
# 94    470
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %%
numbers = pd.Series(data = [1, 2, 3, np.nan, 4, 5])
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.count()
# Out:
# np.int64(5)

# %%
numbers.sum()
# Out:
# np.float64(15.0)

# %%
len(numbers)
# Out:
# 6

# %%
numbers.sum(skipna=False)
# Out:
# np.float64(nan)

# %%
numbers.sum(min_count = 3)
# Out:
# np.float64(15.0)

# %%
numbers.sum(min_count = 6)
# Out:
# np.float64(nan)

# %%
numbers.product()
# Out:
# np.float64(120.0)

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.cumsum()
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
numbers.cumsum(skipna = False)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.pct_change(fill_method='pad')
# Out:
# C:\Users\lorra\AppData\Local\Temp\ipykernel_12584\2455353994.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method='pad')
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

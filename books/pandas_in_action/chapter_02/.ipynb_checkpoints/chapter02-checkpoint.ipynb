# %%
import pandas as pd
import numpy as np

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
ice_cream_flavors = ["Chocolate", "Vanilla", "Strawberry", "Rum Raisin"]

# %%
pd.Series(ice_cream_flavors)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
pd.Series(data=ice_cream_flavors)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
my_series = pd.Series(ice_cream_flavors)
my_series
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
my_series[2]
# Out:
# 'Strawberry'

# %%
my_series[0:2]
# Out:
# 0    Chocolate
# 1      Vanilla
# dtype: object

# %%
days_of_week = ("Monday", "Wednesday", "Friday", "Saturday")
pd.Series(ice_cream_flavors, days_of_week)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Friday       Strawberry
# Saturday     Rum Raisin
# dtype: object

# %%
pd.Series(data=ice_cream_flavors, index=days_of_week)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Friday       Strawberry
# Saturday     Rum Raisin
# dtype: object

# %%
my_favorite_flavor = pd.Series(data=ice_cream_flavors, index=days_of_week)

# %%
my_favorite_flavor["Wednesday"]
# Out:
# 'Vanilla'

# %%
my_favorite_flavor[1]
# Out:
# C:\Users\lorra\AppData\Local\Temp\ipykernel_24268\4194471524.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   my_favorite_flavor[1]
# 'Vanilla'

# %%
my_favorite_flavor.iloc[1]
# Out:
# 'Vanilla'

# %%
bunch_of_bools = [True, False, False]
pd.Series(bunch_of_bools)
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
stock_prices = [985.32, 950.44]
time_of_day = ["Open", "Close"]
pd.Series(data = stock_prices, index = time_of_day)
# Out:
# Open     985.32
# Close    950.44
# dtype: float64

# %%
lucky_numbers = [4, 8, 15, 16, 23, 42]
pd.Series(lucky_numbers)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
lucky_numbers = [4, 8, 15, 16, 23, 42]
pd.Series(lucky_numbers, dtype="float")
# Out:
# 0     4.0
# 1     8.0
# 2    15.0
# 3    16.0
# 4    23.0
# 5    42.0
# dtype: float64

# %%
temperatures = [94, 88, np.nan, 91]
pd.Series(data = temperatures)
# Out:
# 0    94.0
# 1    88.0
# 2     NaN
# 3    91.0
# dtype: float64

# %%
calorie_info = { 
    "Cereal" : 125,
    "Chocolate Bar" : 406,
    "Ice Cream Sundae" : 342,
}
diet = pd.Series(calorie_info)
diet
# Out:
# Cereal              125
# Chocolate Bar       406
# Ice Cream Sundae    342
# dtype: int64

# %%
pd.Series(data= ('Red', 'Green', 'Blue'))
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
# To create a Series that stores tuples, wrap the tuples in a list
rgb_colors = [ (120, 41, 26), (196, 165, 45)]
pd.Series(rgb_colors)
# Out:
# 0     (120, 41, 26)
# 1    (196, 165, 45)
# dtype: object

# %%
my_set = { 'Ricky', 'Bobby' }
pd.Series(data = list(my_set))
# Out:
# 0    Ricky
# 1    Bobby
# dtype: object

# %%
random_data = np.random.randint(1, 101, 10)
random_data
# Out:
# array([81, 18,  1,  8, 54, 31,  3, 31, 54, 88], dtype=int32)

# %%
pd.Series(random_data)
# Out:
# 0    81
# 1    18
# 2     1
# 3     8
# 4    54
# 5    31
# 6     3
# 7    31
# 8    54
# 9    88
# dtype: int32

# %%
type(random_data)
# Out:
# numpy.ndarray

# %%
diet.values
# Out:
# array([125, 406, 342])

# %%
type(diet.values)
# Out:
# numpy.ndarray

# %%
diet.index
# Out:
# Index(['Cereal', 'Chocolate Bar', 'Ice Cream Sundae'], dtype='object')

# %%
type(diet.index)
# Out:
# pandas.core.indexes.base.Index

# %%
diet.dtype
# Out:
# dtype('int64')

# %%
diet.size
# Out:
# 3

# %%
diet.shape
# Out:
# (3,)

# %%
diet.is_unique
# Out:
# True

# %%
pd.Series(data = [3,3]).is_unique
# Out:
# False

# %%
pd.Series(data = [1, 6, 3]).is_monotonic_increasing
# Out:
# False

# %%
pd.Series(data = [1, 6, 3]).is_monotonic_decreasing
# Out:
# False

# %%
# generate 100-value range of numbers between 0 and 500 in increments of 5
values = range(0, 500, 5)
nums = pd.Series(data = values)
nums
# Out:
# 0       0
# 1       5
# 2      10
# 3      15
# 4      20
#      ...
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# Length: 100, dtype: int64

# %%
nums.head(3)
# Out:
# 0     0
# 1     5
# 2    10
# dtype: int64

# %%
nums.tail(6)
# Out:
# 94    470
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %%
numbers = pd.Series(data = [1, 2, 3, np.nan, 4, 5])
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.count()
# Out:
# np.int64(5)

# %%
numbers.sum()
# Out:
# np.float64(15.0)

# %%
len(numbers)
# Out:
# 6

# %%
numbers.sum(skipna=False)
# Out:
# np.float64(nan)

# %%
numbers.sum(min_count = 3)
# Out:
# np.float64(15.0)

# %%
numbers.sum(min_count = 6)
# Out:
# np.float64(nan)

# %%
numbers.product()
# Out:
# np.float64(120.0)

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.cumsum()
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
numbers.cumsum(skipna = False)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.pct_change(fill_method='pad')
# Out:
# C:\Users\lorra\AppData\Local\Temp\ipykernel_24268\2455353994.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method='pad')
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
animals = pd.Series(["koaka", "aardvark", "zebra"])
animals
# Out:
# 0       koaka
# 1    aardvark
# 2       zebra
# dtype: object

# %%
animals.max()
# Out:
# 'zebra'

# %%
animals.min()
# Out:
# 'aardvark'

# %%
animals.describe()
# Out:
# count         3
# unique        3
# top       koaka
# freq          1
# dtype: object

# %%
numbers.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
numbers.sample(3)
# Out:
# 3    NaN
# 4    4.0
# 1    2.0
# dtype: float64

# %%
authors = pd.Series(['Hemingway', 'Orwell', 'Dostoevsky', 'Fitzgerald', 'Orwell'])
authors
# Out:
# 0     Hemingway
# 1        Orwell
# 2    Dostoevsky
# 3    Fitzgerald
# 4        Orwell
# dtype: object

# %%
authors.unique()
# Out:
# array(['Hemingway', 'Orwell', 'Dostoevsky', 'Fitzgerald'], dtype=object)

# %%
authors.nunique()
# Out:
# 4

# %% [markdown]
# ### 2.5.2 Arithmetic operations

# %%
s1 = pd.Series(data = [5, np.nan, 15], index=['A', 'B', 'C'])
s1
# Out:
# A     5.0
# B     NaN
# C    15.0
# dtype: float64

# %%
s1 + 3
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
s1
# Out:
# A     5.0
# B     NaN
# C    15.0
# dtype: float64

# %%
s1.add(3)
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
s1 // 4
# Out:
# A    1.0
# B    NaN
# C    3.0
# dtype: float64

# %%
s1.floordiv(4)
# Out:
# A    1.0
# B    NaN
# C    3.0
# dtype: float64

# %%
s1 = pd.Series([1, 2, 3], index = ["A", "B", "C"])
s2 = pd.Series([4, 5, 6], index = ["A", "B", "C"])

# %%
s1 + s2
# Out:
# A    5
# B    7
# C    9
# dtype: int64

# %%
s1 = pd.Series(data = [3, 6, np.nan, 12])
s2 = pd.Series(data = [3, 6, np.nan, 12])

# %%
s1 == s2
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s1.eq(s2)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s1 != s2
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s1 = pd.Series(
             data = [5, 10, 15], index = ["A", "B", "C"]
         )

# %%
s1
# Out:
# A     5
# B    10
# C    15
# dtype: int64

# %%
s2 = pd.Series(
             data = [4, 8, 12, 14], index = ["B", "C", "D", "E"]
         )
s2
# Out:
# B     4
# C     8
# D    12
# E    14
# dtype: int64

# %%
s1 + s2
# Out:
# A     NaN
# B    14.0
# C    23.0
# D     NaN
# E     NaN
# dtype: float64

# %% [markdown]
# ## 2.6 Passing the Series to Python's built-in functions

# %%
cities = pd.Series(
             data = ["San Francisco", "Los Angeles", "Las  Vegas", np.nan]
         )
cities
# Out:
# 0    San Francisco
# 1      Los Angeles
# 2       Las  Vegas
# 3              NaN
# dtype: object

# %%
len(cities)
# Out:
# 4

# %%
type(cities)
# Out:
# pandas.core.series.Series

# %%
dir(cities)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
list(cities)
# Out:
# ['San Francisco', 'Los Angeles', 'Las  Vegas', nan]

# %%
dict(cities)
# Out:
# {0: 'San Francisco', 1: 'Los Angeles', 2: 'Las  Vegas', 3: nan}

# %%
"Las Vegas" in cities
# Out:
# False

# %%
2 in cities
# Out:
# True

# %%
"Las Vegas" in cities.values
# Out:
# False

# %%
2 in cities.keys()
# Out:
# True

# %%
100 not in cities
# Out:
# True

# %%
"Paris" not in cities.values
# Out:
# True

# %% [markdown]
# ## 2.7 Coding challenge

# %%
# Suppose that you're given these two data structures
superheroes = [
             "Batman",
             "Superman",
             "Spider-Man",
             "Iron Man",
             "Captain America",
             "Wonder Woman"
         ]
strength_levels = (100, 120, 90, 95, 110, 120)

# %% [markdown]
# Here are your challenges:
# 1. Use the list of superheroes to populate a new Series object.
# 2. Use the tuple of strengths to populate a new Series object.
# 3. Create a Series with the superheroes as index labels and the strength levels as the values. Assign the Series to a heroes variable.
# 4. Extract the first two rows of the heroes Series.
# 5. Extract the last four rows of the heroes Series.
# 6. Determine the number of unique values in your heroes Series.
# 7. Calculate the average strength of the superheroes in heroes.
# 8. Calculate the maximum and minimum strengths in heroes.
# 9. Calculate what each superhero’s strength level would be if it doubled.
# 10. Convert the heroes Series to a Python dictionary.

# %%
# 1. Use the list of superheroes to populate a new Series object.
dc_superheroes = pd.Series(superheroes)
dc_superheroes
# Out:
# 0             Batman
# 1           Superman
# 2         Spider-Man
# 3           Iron Man
# 4    Captain America
# 5       Wonder Woman
# dtype: object

# %%
# 2. Use the tuple of strengths to populate a new Series object.
dc_superheros_strength = pd.Series(strength_levels)
dc_superheros_strength
# Out:
# 0    100
# 1    120
# 2     90
# 3     95
# 4    110
# 5    120
# dtype: int64

# %%
# 3. Create a Series with the superheroes as index labels and the strength levels as the values. Assign the Series to a heroes variable.
heroes = pd.Series( data=strength_levels, index=superheroes)
heroes
# Out:
# Batman             100
# Superman           120
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
# 4. Extract the first two rows of the heroes Series. (could have used head(2))
heroes[:2]
# Out:
# Batman      100
# Superman    120
# dtype: int64

# %%
# 5. Extract the last four rows of the heroes Series. (could have used tail(4))
heroes[-4:]
# Out:
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
# 6. Determine the number of unique values in your heroes Series. (note: this looks at the values! not the index)
heroes.nunique()
# Out:
# 5

# %%
heroes
# Out:
# Batman             100
# Superman           120
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
# 7. Calculate the average strength of the superheroes in heroes (use mean())
heroes.sum() / len(heroes)
# Out:
# np.float64(105.83333333333333)

# %%
# 8. Calculate the maximum and minimum strengths in heroes.
print(heroes.max())
print(heroes.min())
# Out:
# 120
# 90

# %%
# 9. Calculate what each superhero’s strength level would be if it doubled.
heroes * 2
# Out:
# Batman             200
# Superman           240
# Spider-Man         180
# Iron Man           190
# Captain America    220
# Wonder Woman       240
# dtype: int64

# %%
# 10. Convert the heroes Series to a Python dictionary.
dict(heroes)
# Out:
# {'Batman': np.int64(100),
#  'Superman': np.int64(120),
#  'Spider-Man': np.int64(90),
#  'Iron Man': np.int64(95),
#  'Captain America': np.int64(110),
#  'Wonder Woman': np.int64(120)}

# %% [markdown]
# # Critical Thinking

# %% [markdown]
# ## 1. For each dataset (https://openstax.org/r/spreadsheetsd1), list the attributes.
#
# a. Spotify dataset
# b. CancerDoc dataset

# %%
import pandas as pd
spotify_df = pd.read_csv("ch1-spotify-2023.csv")
# list of attributes for spotify dataset
spotify_df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
spotify_df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
cancerdoc_df = pd.read_csv("ch1-cancerdoc.csv")
# list of attributes for cancerdoc dataset
cancerdoc_df.columns
# Out:
# Index(['Unnamed: 0', '0', 'a'], dtype='object')

# %%
cancerdoc_df.head()
# Out:
#    Unnamed: 0               0  \
# 0           0  Thyroid_Cancer
# 1           1  Thyroid_Cancer
# 2           2  Thyroid_Cancer
# 3           3  Thyroid_Cancer
# 4           4  Thyroid_Cancer
#
#                                                    a
# 0  Thyroid surgery in  children in a single insti...
# 1  " The adopted strategy was the same as that us...
# 2  coronary arterybypass grafting thrombosis Ô¨Åb...
# 3   Solitary plasmacytoma SP of the skull is an u...
# 4   This study aimed to investigate serum matrix ...

# %% [markdown]
# ## 2. For each dataset (https://openstax.org/r/spreadsheetsd1), define the type of the data based on following criteria and explain why:
#
# • Numeric vs. categorical
# • If it is numeric, continuous vs. discrete; if it is categorical, nominal vs. ordinal
#
# a. “artist_count” attribute of Spotify dataset
# b. “mode” attribute of Spotify dataset
# c. “key” attribute of Spotify dataset
# d. the second column in CancerDoc dataset

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
# artist_count is numeric and discrete
spotify_df['artist_count'].value_counts()
# Out:
# artist_count
# 1    587
# 2    254
# 3     85
# 4     15
# 5      5
# 6      3
# 8      2
# 7      2
# Name: count, dtype: int64

# %%
# mode is categorical and ordinal (Minor, Major)
spotify_df['mode'].value_counts()
# Out:
# mode
# Major    550
# Minor    403
# Name: count, dtype: int64

# %%
# key attribute is categorical and ordinal
spotify_df['key'].value_counts()
# Out:
# key
# C#    120
# G      96
# G#     91
# F      89
# B      81
# D      81
# A      75
# F#     73
# E      62
# A#     57
# D#     33
# Name: count, dtype: int64

# %%
# d. the second column in CancerDoc dataset 
# Answer: catetof
cancerdoc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7570 entries, 0 to 7569
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7570 non-null   int64
#  1   0           7570 non-null   object
#  2   a           7110 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 177.6+ KB

# %%
cancerdoc_df.head()
# Out:
#    Unnamed: 0               0  \
# 0           0  Thyroid_Cancer
# 1           1  Thyroid_Cancer
# 2           2  Thyroid_Cancer
# 3           3  Thyroid_Cancer
# 4           4  Thyroid_Cancer
#
#                                                    a
# 0  Thyroid surgery in  children in a single insti...
# 1  " The adopted strategy was the same as that us...
# 2  coronary arterybypass grafting thrombosis Ô¨Åb...
# 3   Solitary plasmacytoma SP of the skull is an u...
# 4   This study aimed to investigate serum matrix ...

# %%
# column is categorical, nominal
cancerdoc_df["0"].value_counts()
# Out:
# 0
# Thyroid_Cancer    2810
# Colon_Cancer      2580
# Lung_Cancer       2180
# Name: count, dtype: int64

# %% [markdown]
# ## 3. For each dataset (https://openstax.org/r/spreadsheetsd1), identify the type of the dataset—structured vs. unstructured. Explain why.
#
# a. Spotify dataset
# b. CancerDoc dataset

# %%
spotify_df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# spotify data appears structured

# %%
cancerdoc_df.head()
# Out:
#    Unnamed: 0               0  \
# 0           0  Thyroid_Cancer
# 1           1  Thyroid_Cancer
# 2           2  Thyroid_Cancer
# 3           3  Thyroid_Cancer
# 4           4  Thyroid_Cancer
#
#                                                    a
# 0  Thyroid surgery in  children in a single insti...
# 1  " The adopted strategy was the same as that us...
# 2  coronary arterybypass grafting thrombosis Ô¨Åb...
# 3   Solitary plasmacytoma SP of the skull is an u...
# 4   This study aimed to investigate serum matrix ...

# %%
# cancerdoc appears to be unstructured (but forced into a structure)

# %% [markdown]
# ## 4. For each dataset (https://openstax.org/r/spreadsheetsd1), list the first data entry.
#
# a. Spotify dataset
# b. CancerDoc dataset

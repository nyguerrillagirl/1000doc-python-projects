# %%
1234
# Out:
# 1234

# %%
message = "Goodbye World"

# %%
# printing my first message
print("Hello world!")
# Out:
# Hello world!

# %%
"Hello world!"
# Out:
# 'Hello world!'

# %%
# printing my name
print("Lorraine Figueroa")
# Out:
# Lorraine Figueroa

# %%
print(69.5)
# Out:
# 69.5

# %%
type("This is a string")
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
"Hello world!".upper()
# Out:
# 'HELLO WORLD!'

# %%
"Hello world!".lower()
# Out:
# 'hello world!'

# %%
"Hello world!".title()
# Out:
# 'Hello World!'

# %%
"Hello world!".count('l')
# Out:
# 3

# %%
"Hello world!".replace('l', 'L')
# Out:
# 'HeLLo worLd!'

# %% [markdown]
# # Variables

# %%
message_1 = "I'm learning Python."

# %%
message_1
# Out:
# "I'm learning Python."

# %%
message_2 = "I am starting to love it"
message_2
# Out:
# 'I am starting to love it'

# %%
message_1 + message_2
# Out:
# "I'm learning Python.I am starting to love it"

# %%
message_1 + " " + message_2
# Out:
# "I'm learning Python. I am starting to love it"

# %%
f'Hello, World!'
# Out:
# 'Hello, World!'

# %%
f'{message_1}'
# Out:
# "I'm learning Python."

# %%
f'{message_1} {message_2}'
# Out:
# "I'm learning Python. I am starting to love it"

# %%
f'{message_1} ABC {message_2}'
# Out:
# "I'm learning Python. ABC I am starting to love it"

# %% [markdown]
# # List

# %%
countries = ['United States', 'India', 'China', 'Brazil']
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
strange_list = ['Oh My!', True, 100, 45.0]
strange_list
# Out:
# ['Oh My!', True, 100, 45.0]

# %%
countries[0]
# Out:
# 'United States'

# %% [markdown]
# ### Adding elements to a list

# %%
countries.append('Canada')
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries_1 = countries
countries_2 = ['Germany', 'France', 'Norway']
countries_2
# Out:
# ['Germany', 'France', 'Norway']

# %%
countries_1 + countries_2
# Out:
# ['United States',
#  'India',
#  'China',
#  'Brazil',
#  'Canada',
#  'Germany',
#  'France',
#  'Norway']

# %%
nested_list = [countries_1, countries_2]
nested_list
# Out:
# [['United States', 'India', 'China', 'Brazil', 'Canada'],
#  ['Germany', 'France', 'Norway']]

# %%
print(nested_list[0])
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
print(nested_list[1][1])
# Out:
# France

# %%
list_1 = [1, 2, 1, 3]
list_1
# Out:
# [1, 2, 1, 3]

# %%
list_1.remove(1)
list_1
# Out:
# [2, 1, 3]

# %%
list_1.remove(1)
list_1
# Out:
# [2, 3]

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries.pop(-1)
# Out:
# 'Canada'

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
numbers = [4, 3, 10, 7, 1, 2]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4, 7, 10]

# %%
numbers = [4, 3, 10, 7, 1, 2]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %%
numbers[0] = 1000
numbers
# Out:
# [1000, 7, 4, 3, 2, 1]

# %%
new_list = [2, 3, 18, 5, 5, 100]

# %%
another_list = [1000 if x % 2 != 0 else x for x in new_list]
another_list
# Out:
# [2, 1000, 18, 1000, 1000, 100]

# %%
countries = ['United States', 'India', 'China', 'Brazil', 'Canada']
new_list = countries[:]

# %%
new_list
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
new_list[1] = 'Mexico'
new_list
# Out:
# ['United States', 'Mexico', 'China', 'Brazil', 'Canada']

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
new_list_1 = countries
new_list_1
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
new_list_1[1] = 'Mexico'
new_list_1
# Out:
# ['United States', 'Mexico', 'China', 'Brazil', 'Canada']

# %%
countries
# Out:
# ['United States', 'Mexico', 'China', 'Brazil', 'Canada']

# %% [markdown]
# # Dictionary

# %%
my_dict = {'key2': 'value1', 'key2':'value2'}

# %%
my_data = {'name': 'Lorraine', 'age': 69, 'occupation':'programmer' }
my_data
# Out:
# {'name': 'Lorraine', 'age': 69, 'occupation': 'programmer'}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age', 'occupation'])

# %%
my_data.values()
# Out:
# dict_values(['Lorraine', 69, 'programmer'])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Lorraine'), ('age', 69), ('occupation', 'programmer')])

# %%
my_data['hobby'] = 'playing AOE2'
my_data
# Out:
# {'name': 'Lorraine',
#  'age': 69,
#  'occupation': 'programmer',
#  'hobby': 'playing AOE2'}

# %%
my_data.update({'occupation': 'retired'})
my_data
# Out:
# {'name': 'Lorraine',
#  'age': 69,
#  'occupation': 'retired',
#  'hobby': 'playing AOE2'}

# %%
my_data.pop('occupation')
# Out:
# 'retired'

# %%
my_data
# Out:
# {'name': 'Lorraine', 'age': 69, 'hobby': 'playing AOE2'}

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\300-days-of-code\\src\\python_projects\\freecodecamp_data_science\\anaconda_projects'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '65a8abbd-5a2f-4e1c-acc3-5b6e891aeb4e',
#  'anaconda_projects',
#  'db',
#  'Example02.ipynb',
#  'python-for-data-science-main']

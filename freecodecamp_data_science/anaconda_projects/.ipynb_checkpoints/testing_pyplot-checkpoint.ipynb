# %%
import pandas as pd
import plotly.express as px

# Create a simple DataFrame
df = pd.DataFrame({'x': [1, 2, 3], 'y': [4, 5, 6]})

# Plot using Plotly Express
fig = px.line(df, x='x', y='y', title='Plotly Express Test')
fig.show()

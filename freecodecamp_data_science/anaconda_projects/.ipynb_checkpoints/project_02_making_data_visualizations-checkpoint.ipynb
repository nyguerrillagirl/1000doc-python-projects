# %% [markdown]
# # Project #2: Making Static and Interactive Data Visualization

# %%
import pandas as pd

# %%
# reading the csv file
df_population_raw = pd.read_csv("population_total.csv")

# %%
# first look at the dataset
df_population_raw.head()
# Out:
#   country    year    population
# 0   China  2020.0  1.439324e+09
# 1   China  2019.0  1.433784e+09
# 2   China  2018.0  1.427648e+09
# 3   China  2017.0  1.421022e+09
# 4   China  2016.0  1.414049e+09

# %% [markdown]
# ## 1. Making a Pivot Table
#
# .pivot(): returns reshaped DataFrame organized by given index/column values ("pivot without aggregation")

# %%
# dropping null values
df_population_raw.dropna(inplace=True)

# %%
# making a pivot table
# want to make 'year' column to be the index
df_pivot = df_population_raw.pivot(index='year', columns="country", values="population")

# %%
# select some countries
df_pivot = df_pivot[['United States', 'India', 'China', 'Indonesia', 'Brazil']]

# %%
# showing pivot table
df_pivot
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1955.0     171685336.0  4.098806e+08  6.122416e+08   77273425.0   62533919.0
# 1960.0     186720571.0  4.505477e+08  6.604081e+08   87751068.0   72179226.0
# 1965.0     199733676.0  4.991233e+08  7.242190e+08  100267062.0   83373530.0
# 1970.0     209513341.0  5.551898e+08  8.276014e+08  114793178.0   95113265.0
# 1975.0     219081251.0  6.231029e+08  9.262409e+08  130680727.0  107216205.0
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1985.0     240499825.0  7.843600e+08  1.075589e+09  164982451.0  135274080.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 1995.0     265163745.0  9.639226e+08  1.240921e+09  196934260.0  162019896.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2005.0     294993511.0  1.147610e+09  1.330776e+09  226289470.0  186127103.0
# 2010.0     309011475.0  1.234281e+09  1.368811e+09  241834215.0  195713635.0
# 2015.0     320878310.0  1.310152e+09  1.406848e+09  258383256.0  204471769.0
# 2016.0     323015995.0  1.324517e+09  1.414049e+09  261556381.0  206163053.0
# 2017.0     325084756.0  1.338677e+09  1.421022e+09  264650963.0  207833823.0
# 2018.0     327096265.0  1.352642e+09  1.427648e+09  267670543.0  209469323.0
# 2019.0     329064917.0  1.366418e+09  1.433784e+09  270625568.0  211049527.0
# 2020.0     331002651.0  1.380004e+09  1.439324e+09  273523615.0  212559417.0

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Lineplot

# %%
df_pivot.plot(kind="line", xlabel="Year", ylabel="Population", title="Population (1955-2020)", figsize=(8, 4))

# save plot
plt.savefig('my_test.png')

# show plot
plt.show()

# %%
df_pivot.to_excel('pivot_table.xlsx')

# %% [markdown]
# ## 3. Barplot

# %% [markdown]
# ### 3.1 Single Barplot

# %%
# selecting only one year (2020)
df_pivot_2020 = df_pivot[df_pivot.index.isin([2020])]

# %%
# showing new dataframe
df_pivot_2020
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 2020.0     331002651.0  1.380004e+09  1.439324e+09  273523615.0  212559417.0

# %%
# transpose dataframe from rows to columns or vice versa
df_pivot_2020 = df_pivot_2020.T

# %%
# making barplot
df_pivot_2020.plot(kind="bar", color="orange", xlabel="Year", ylabel="Population", title="Population (2020)")
# Out:
# <Axes: title={'center': 'Population (2020'}, xlabel='Year', ylabel='Population'>

# %% [markdown]
# ### 3.2 Barplot grouped by "n" variables

# %%
# selecting a few years
df_pivot_sample = df_pivot[df_pivot.index.isin([1980, 1990, 2000, 2010, 2020])]
df_pivot_sample
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2010.0     309011475.0  1.234281e+09  1.368811e+09  241834215.0  195713635.0
# 2020.0     331002651.0  1.380004e+09  1.439324e+09  273523615.0  212559417.0

# %%
# making grouped barplot
df_pivot_sample.plot(kind="bar", xlabel="Year", ylabel="Population")
# Out:
# <Axes: xlabel='Year', ylabel='Population'>

# %% [markdown]
# ## 4. Piechart

# %%
# changing column name
df_pivot_2020.rename(columns={2020: '2020'}, inplace=True)
df_pivot_2020
# Out:
# year                   2020
# country
# United States  3.310027e+08
# India          1.380004e+09
# China          1.439324e+09
# Indonesia      2.735236e+08
# Brazil         2.125594e+08

# %%
# making the plot
df_pivot_2020.plot(kind="pie", y='2020', title="Population in 2020(%)")
# Out:
# <Axes: title={'center': 'Population in 2020(%)'}, ylabel='2020'>

# %% [markdown]
# ## 5. Boxplot

# %% [markdown]
# ### 5.1 Single Boxplot

# %%
df_pivot["United States"].plot(kind="box", color="green", ylabel="Population")
# Out:
# <Axes: ylabel='Population'>

# %% [markdown]
# ### 5.2 Multiple Boxplot

# %%
df_pivot.plot(kind="box", color="green", ylabel="Population")
# Out:
# <Axes: ylabel='Population'>

# %% [markdown]
# ## 6 Histogram

# %%
df_pivot[["Indonesia", "United States"]].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## 7 ScatterPlot

# %%
# selecting a sample of the raw data
df_sample =  df_population_raw[df_population_raw['country'].isin(['United States', 'India', 'China', 'Indonesia', 'Brazil'])]

# %%
# creating the plot
df_sample.plot(kind="scatter", x = "year" , y="population", s=80, color="green" )
# Out:
# <Axes: xlabel='year', ylabel='population'>

# %% [markdown]
# # Interactive Visualization with plotly

# %% [markdown]
# # DUE TO THE INABILITY TO HAVE cufflinks and plotly work
# ## Replacing code with plotly.express as px

# %%
#!pip install cufflinks
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df_population_raw = pd.read_csv("population_total.csv")
df_population_raw.head()
# Out:
#   country    year    population
# 0   China  2020.0  1.439324e+09
# 1   China  2019.0  1.433784e+09
# 2   China  2018.0  1.427648e+09
# 3   China  2017.0  1.421022e+09
# 4   China  2016.0  1.414049e+09

# %%
# dropping null values
df_population_raw.dropna(inplace=True)

# making a pivot table
# want to make 'year' column to be the index
df_pivot = df_population_raw.pivot(index='year', columns="country", values="population")

# select some countries
df_pivot = df_pivot[['United States', 'India', 'China', 'Indonesia', 'Brazil']]

# showing the pivot table
df_pivot
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1955.0     171685336.0  4.098806e+08  6.122416e+08   77273425.0   62533919.0
# 1960.0     186720571.0  4.505477e+08  6.604081e+08   87751068.0   72179226.0
# 1965.0     199733676.0  4.991233e+08  7.242190e+08  100267062.0   83373530.0
# 1970.0     209513341.0  5.551898e+08  8.276014e+08  114793178.0   95113265.0
# 1975.0     219081251.0  6.231029e+08  9.262409e+08  130680727.0  107216205.0
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1985.0     240499825.0  7.843600e+08  1.075589e+09  164982451.0  135274080.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 1995.0     265163745.0  9.639226e+08  1.240921e+09  196934260.0  162019896.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2005.0     294993511.0  1.147610e+09  1.330776e+09  226289470.0  186127103.0
# 2010.0     309011475.0  1.234281e+09  1.368811e+09  241834215.0  195713635.0
# 2015.0     320878310.0  1.310152e+09  1.406848e+09  258383256.0  204471769.0
# 2016.0     323015995.0  1.324517e+09  1.414049e+09  261556381.0  206163053.0
# 2017.0     325084756.0  1.338677e+09  1.421022e+09  264650963.0  207833823.0
# 2018.0     327096265.0  1.352642e+09  1.427648e+09  267670543.0  209469323.0
# 2019.0     329064917.0  1.366418e+09  1.433784e+09  270625568.0  211049527.0
# 2020.0     331002651.0  1.380004e+09  1.439324e+09  273523615.0  212559417.0

# %% [markdown]
# ## 1. Interactive Lineplot

# %%
import numpy as np

px.line(df_pivot, title='Population(1955-2020)', labels={'x': 'Years', 'value': 'Population'} )

# %% [markdown]
# ## 2. Barplot with plotly

# %%
df_pivot_2020 = df_pivot[df_pivot.index.isin([2020])]
# transpose dataframe from rows to columns or vice versa
df_pivot_2020 = df_pivot_2020.T

# %%
df_pivot_2020
# Out:
# year                 2020.0
# country
# United States  3.310027e+08
# India          1.380004e+09
# China          1.439324e+09
# Indonesia      2.735236e+08
# Brazil         2.125594e+08

# %%
df_pivot_2020.columns
# Out:
# Index([2020.0], dtype='float64', name='year')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 fig = px.bar(df_pivot_2020, x = '[2020.0]', y='year', color='lightgreen', title='Population in 2020', labels={'country': 'Country', 'value': 'Population'})
#
# File ~\.conda\envs\datasci\Lib\site-packages\plotly\express\_chart_types.py:381, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, subtitle, template, width, height)
#     332 def bar(
#     333     data_frame=None,
#     334     x=None,
#    (...)    375     height=None,
#     376 ) -> go.Figure:
#     377     """
#     378     In a bar plot, each row of `data_frame` is represented as a rectangular
#     379     mark.
#     380     """
# --> 381     return make_figure(
#     382         args=locals(),
#     383         constructor=go.Bar,
#     384         trace_patch=dict(textposition="auto"),
#     385         layout_patch=dict(barmode=barmode),
#     386     )
#
# File ~\.conda\envs\datasci\Lib\site-packages\plotly\express\_core.py:2491, in make_figure(args, constructor, trace_patch, layout_patch)
#    2488 layout_patch = layout_patch or {}
#    2489 apply_default_cascade(args)
# -> 2491 args = build_dataframe(args, constructor)
#    2492 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2493     args = process_dataframe_hierarchy(args)
#
# File ~\.conda\envs\datasci\Lib\site-packages\plotly\express\_core.py:1737, in build_dataframe(args, constructor)
#    1734     args["color"] = None
#    1735 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1737 df_output, wide_id_vars = process_args_into_dataframe(
#    1738     args,
#    1739     wide_mode,
#    1740     var_name,
#    1741     value_name,
#    1742     is_pd_like,
#    1743     native_namespace,
#    1744 )
#    1745 df_output: nw.DataFrame
#    1746 # now that `df_output` exists and `args` contains only references, we complete
#    1747 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1748 # df_output
#
# File ~\.conda\envs\datasci\Lib\site-packages\plotly\express\_core.py:1338, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1336         if argument == "index":
#    1337             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1338         raise ValueError(err_msg)
#    1339 elif length and (actual_len := len(df_input)) != length:
#    1340     raise ValueError(
#    1341         "All arguments should have the same length. "
#    1342         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)   1349         )
#    1350     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of [2020.0] but received: [2020.0]

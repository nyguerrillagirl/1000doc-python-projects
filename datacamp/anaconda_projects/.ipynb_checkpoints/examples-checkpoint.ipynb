# %%
import numpy as np
import pandas as pd

# %%
# Create an untidy data set
dict = { "Sara" : ["27", 1.77, "Belgium"],
         "Lis": ["30", 5.58, "USA"],
         "Hadrien" : ["", 1.80, "FR"],
         "Lis": ["30", 5.58, "USA"]}

# %%
df = pd.DataFrame(dict, index = ["Age", "Size", "Country"])
df
# Out:
#             Sara   Lis Hadrien
# Age           27    30
# Size        1.77  5.58     1.8
# Country  Belgium   USA      FR

# %%
list(df.columns)
# Out:
# ['Sara', 'Lis', 'Hadrien']

# %%
list(df.index)
# Out:
# ['Age', 'Size', 'Country']

# %%
df
# Out:
#             Sara   Lis Hadrien
# Age           27    30
# Size        1.77  5.58     1.8
# Country  Belgium   USA      FR

# %%
df.T
# Out:
#         Age  Size  Country
# Sara     27  1.77  Belgium
# Lis      30  5.58      USA
# Hadrien       1.8       FR

# %%
df = df.T
df
# Out:
#         Age  Size  Country
# Sara     27  1.77  Belgium
# Lis      30  5.58      USA
# Hadrien       1.8       FR

# %%
df.reset_index()
# Out:
#      index Age  Size  Country
# 0     Sara  27  1.77  Belgium
# 1      Lis  30  5.58      USA
# 2  Hadrien       1.8       FR
